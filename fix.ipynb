# %% [markdown]
# <a href="https://colab.research.google.com/github/yunikurniatr/BrainTumorDetection/blob/main/fix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
import cv2 as cv2
filename = ('/content/drive/MyDrive/PCVK/Brain Tumor/Y8.jpg')
img = cv2.imread(filename,0) 
blur = cv2. GaussianBlur (img, (5,5),0)

ret, th1 = cv2.threshold(blur, 160, 255, cv2.THRESH_BINARY)

edged = cv.Canny(th1, 30, 200)
 
contours, hierarchy = cv.findContours(edged, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_NONE)

cv.drawContours(img, contours, -1, (255,255,0), 3)

titles = ['Citra Asli', 'Hasil global threshold', 'Hasil Deteksi tumor'] 
citra = cv.cvtColor(img, cv.COLOR_BGR2RGB)
citra3 = [blur, th1, citra]

plt. figure(figsize = (20,20)) 

for i in range(len(citra3)):
    plt. subplot(1,3,i+1),plt.imshow(citra3[i], 'gray') 
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([]) 
plt.show()
